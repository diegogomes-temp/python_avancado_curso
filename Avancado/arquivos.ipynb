# %%
reportagem = open("arquivo.txt", "r", encoding="utf-8")
#print(reportagem.read())
#print(reportagem.read(5)) # Lê os próximos 5 caracteres do arquivo
#print(reportagem.readline()) # Lê a próxima linha do arquivo
#print(reportagem.readlines()) # Lê as próximas linhas do arquivo

# %%
print(len(reportagem.readlines())) # Conta quantas linhas restam no arquivo
# Out:
# 15

# %%
#contando as palavras do arquivo
palavras = reportagem.read()
lista_palavras = palavras.split()
print(len(lista_palavras))  # Imprime o número de palavras no arquivo
# Out:
# 558

# %%
set_palavras = set(lista_palavras)
print(len(set_palavras))  # Imprime o número de palavras únicas no arquivo
# Out:
# 378
